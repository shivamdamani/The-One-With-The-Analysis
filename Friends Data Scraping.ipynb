# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd

# %%
driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')

# %%
driver.get("https://fangj.github.io/friends/season/0101.html")

# %%
s1 = driver.find_element_by_xpath("/html/body").text
driver.close()

# %%
s1 = s1.split("\n")

# %%
dialogues = s1[5:]

# %%
name = []
dialogue = []

# %%
for line in dialogues:
    if line.find(":") != -1 and line[0].isalpha():
        s = line.split(":")
        name.append(s[0])
        dialogue.append(s[1])

# %%
episode_1 = pd.DataFrame(name, columns=['name'])

# %%
episode_1['dialogue']=dialogue

# %%
episode_1.tail()
# Out:
#          name                                           dialogue
# 295       All             Yeah. Yeah, I'll have a cup of coffee.
# 296  Chandler   Kids, new dream... I'm in Las Vegas. (Rachel ...
# 297  Customer              (To Rachel) Ahh, miss?   More coffee?
# 298    Rachel   Ugh. (To another customer that's leaving.) Ex...
# 299  Chandler    Okay, so, I'm in Las Vegas... I'm Liza Minelli-

# %%
for i in range(1,2):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/01"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(1)
            e_count.append(i)
    season_1 = pd.DataFrame(name, columns=['name'])
    season_1['dialogue'] = dialogue
    season_1['season'] = s_count
    season_1['episode'] = e_count
for i in range(2,25):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/01"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(1)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_1, temp]
    season_1 = pd.concat(frames)

# %%
season_1.index = range(season_1.shape[0])
season_1

# %%
for i in range(1,2):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/02"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(2)
            e_count.append(i)
    season_2 = pd.DataFrame(name, columns=['name'])
    season_2['dialogue'] = dialogue
    season_2['season'] = s_count
    season_2['episode'] = e_count
for i in range(2,25):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/02"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(2)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_2, temp]
    season_2 = pd.concat(frames)
season_2.index = range(season_2.shape[0])
season_2

# %%
for i in range(1,2):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/03"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(3)
            e_count.append(i)
    season_3 = pd.DataFrame(name, columns=['name'])
    season_3['dialogue'] = dialogue
    season_3['season'] = s_count
    season_3['episode'] = e_count
for i in range(2,26):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/03"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(3)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_3, temp]
    season_3 = pd.concat(frames)
season_3.index = range(season_3.shape[0])
season_3

# %%
for i in range(1,2):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/04"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(4)
            e_count.append(i)
    season_4 = pd.DataFrame(name, columns=['name'])
    season_4['dialogue'] = dialogue
    season_4['season'] = s_count
    season_4['episode'] = e_count
for i in range(2,24):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/04"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(4)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_4, temp]
    season_4 = pd.concat(frames)
season_4.index = range(season_4.shape[0])
season_4

# %%
for i in range(1,2):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/05"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(5)
            e_count.append(i)
    season_5 = pd.DataFrame(name, columns=['name'])
    season_5['dialogue'] = dialogue
    season_5['season'] = s_count
    season_5['episode'] = e_count
for i in range(2,24):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/05"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(5)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_5, temp]
    season_5 = pd.concat(frames)
season_5.index = range(season_5.shape[0])
season_5

# %%
for i in range(1,2):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/06"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(6)
            e_count.append(i)
    season_6 = pd.DataFrame(name, columns=['name'])
    season_6['dialogue'] = dialogue
    season_6['season'] = s_count
    season_6['episode'] = e_count
for i in range(2,25):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/06"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(6)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_6, temp]
    season_6 = pd.concat(frames)
season_6.index = range(season_6.shape[0])
season_6

# %%
for i in range(1,2):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/07"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(7)
            e_count.append(i)
    season_7 = pd.DataFrame(name, columns=['name'])
    season_7['dialogue'] = dialogue
    season_7['season'] = s_count
    season_7['episode'] = e_count
for i in range(2,24):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/07"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(7)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_7, temp]
    season_7 = pd.concat(frames)
season_7.index = range(season_7.shape[0])
season_7

# %%
for i in range(1,2):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/08"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(8)
            e_count.append(i)
    season_8 = pd.DataFrame(name, columns=['name'])
    season_8['dialogue'] = dialogue
    season_8['season'] = s_count
    season_8['episode'] = e_count
for i in range(2,24):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/08"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(8)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_8, temp]
    season_8 = pd.concat(frames)
season_8.index = range(season_8.shape[0])
season_8

# %%
for i in range(1,2):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/09"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(9)
            e_count.append(i)
    season_9 = pd.DataFrame(name, columns=['name'])
    season_9['dialogue'] = dialogue
    season_9['season'] = s_count
    season_9['episode'] = e_count
for i in range(2,23):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/09"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(9)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_9, temp]
    season_9 = pd.concat(frames)

    
    
    
    
for i in range(23,24):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/0923-0924.html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(9)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_9, temp]
    season_9 = pd.concat(frames)
season_9.index = range(season_9.shape[0])
season_9

# %%
for i in range(1,2):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/10"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(10)
            e_count.append(i)
    season_10 = pd.DataFrame(name, columns=['name'])
    season_10['dialogue'] = dialogue
    season_10['season'] = s_count
    season_10['episode'] = e_count
for i in range(2,17):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/10"+add+".html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(10)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_10, temp]
    season_10 = pd.concat(frames)

    
    
    
    
for i in range(17,18):
    if i<10:
        add = '0'+str(i)
    else:
        add = str(i)
    link = "https://fangj.github.io/friends/season/1017-1018.html"
    driver = webdriver.Chrome('C:\\Users\\Shivam\\Desktop\\Friends\\chromedriver.exe')
    driver.get(link)
    s1 = driver.find_element_by_xpath("/html/body").text
    driver.close()
    s1 = s1.split("\n")
    dialogues = s1[5:]
    name = []
    dialogue = []
    s_count = []
    e_count = []
    for line in dialogues:
        if line.find(":") != -1 and line[0].isalpha():
            s = line.split(":")
            name.append(s[0])
            dialogue.append(s[1])
            s_count.append(10)
            e_count.append(i)
    temp = pd.DataFrame(name, columns=['name'])
    temp['dialogue'] = dialogue
    temp['season'] = s_count
    temp['episode'] = e_count
    frames = [season_10, temp]
    season_10 = pd.concat(frames)
season_10.index = range(season_10.shape[0])
season_10

# %%
frames = [season_1, season_2,season_3,season_4,season_5,season_6,season_7,season_8,season_9,season_10]
master = pd.concat(frames)
master.index = range(master.shape[0])
master

# %%
master.to_csv('Master.csv')
